# %% [markdown]
# #Task1: Time‑Series Analysis of Precipitation
# Note: Do the tasks under Task 1 using any of the grid cell(lat-lon) data (not on whole grid)

# %% [markdown]
# ##1.1 Load & Inspect
#
# Read data into a DataFrame.
#
# Display head and check for missing values.

# %% [markdown]
# ##1.2 Visualize the Series
#
# For one representative grid cell (pick a lat‑lon), plot monthly precip over time.
#
# Use a rolling mean (window=12) to highlight seasonal cycles.

# %% [markdown]
# ##1.3 Decomposition
#
# Decompose the same single‑cell series into trend, seasonal, and residual components (e.g. via statsmodels.tsa.seasonal_decompose).

# %% [markdown]
# ## 1.4 Stationarity Tests
#
# Apply Augmented Dickey–Fuller (ADF) and KPSS tests.
#
# Interpret p‑values: is the raw series stationary? If not, how many differences are needed?

# %% [markdown]
# Converting Non-Stationary time serie to Stationary (USING DIFFERENCING)

# %% [markdown]
# ## 1.5 Seasonality Check
#
# Plot ACF and PACF up to 24 lags.
#
# Comment on significant seasonal lags.

# %% [markdown]
# ### Autocorrelation and Partial Autocorrelation Functions

# %% [markdown]
# - The ACF shows clear spikes at lags 12, 24 indicating a strong yearly seasonality.
# - The PACF shows significant spikes at lags 1 and 12, meaning:
# -Lag 1: Some short-term (month-to-month) dependence.
# -Lag 12: Strong seasonal dependence — confirms annual cycle again.

# %% [markdown]
# #TASK 2: Change‑Point Detection

# %% [markdown]
# ##2.1 CUSUM Method
#
# Use a Python library (e.g. ruptures or your own CUSUM code) to identify any abrupt shifts in mean precipitation for the chosen grid cell.
#
# Plot the time series with vertical lines at detected change‑points.

# %% [markdown]
# Group locations by lat-lon and collect observation values to NumPy array

# %%
# !pip install indsl
from indsl.detect.cusum import Cusum
# Out:
# Requirement already satisfied: indsl in /usr/local/lib/python3.11/dist-packages (8.6.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from indsl) (1.26.4)
# Requirement already satisfied: packaging<24.0,>=23.0 in /usr/local/lib/python3.11/dist-packages (from indsl) (23.2)
# Requirement already satisfied: pandas<2.3.0,>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from indsl) (2.2.2)
# Requirement already satisfied: pywavelets<2.0.0,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from indsl) (1.8.0)
# Requirement already satisfied: scipy<1.13.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from indsl) (1.12.0)
# Requirement already satisfied: typeguard<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from indsl) (4.4.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.6.3 in /usr/local/lib/python3.11/dist-packages (from indsl) (4.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=2.2.0->indsl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=2.2.0->indsl) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=2.2.0->indsl) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=2.2.0->indsl) (1.17.0)
# /usr/local/lib/python3.11/dist-packages/indsl/equipment/volume_vessel.py:32: IndslUserWarning: Couldn't import fluids.numba_vectorized: No module named 'fluids'. Default to import fluids.vectorized.
#   warnings.warn(

# %% [markdown]
# ## 2.2 PELT Algorithm
#
# Apply the PELT method (ruptures.Pelt) on the same series.

# %% [markdown]
# #TASK 3: Trend Analysis (Apply on whole grid)

# %% [markdown]
# ## 3.2 Mann–Kendall Test
#
# For each grid cell, compute the Mann–Kendall trend test on its precipitation series (1980–2023).

# %%
# install the pymannkendall library for trend analysis
! pip install pymannkendall
# Out:
# Collecting pymannkendall
#   Downloading pymannkendall-1.4.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pymannkendall) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pymannkendall) (1.12.0)
# Downloading pymannkendall-1.4.3-py3-none-any.whl (12 kB)
# Installing collected packages: pymannkendall
# Successfully installed pymannkendall-1.4.3

# %% [markdown]
# ##3.3 Seasonal Mann–Kendall
#
# Apply SMK Test on the given dataset and observe the result of MK and SMK Test

# %% [markdown]
# Apply for one location
