# %% [markdown]
# # Neural Networks for Classification with TensorFlow/Keras
# **Author:** Dr. Rishikesh Yadav / Vedant Vibhor
#
# This notebook demonstrates how to build, train, evaluate, and visualize a simple neural network for binary classification using TensorFlow/Keras. The workflow closely follows the structure of the original classification example, but uses TensorFlow.

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# ## Generate Synthetic Data

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Number of samples
n = 1000

# Generate two input features from a standard normal distribution
x1 = np.random.normal(0, 1, n)
x2 = np.random.normal(0, 1, n)

# Generate binary target: points outside a noisy circle are class 1, inside are class 0
y = ((x1**2 + x2**2 + np.random.normal(0, 1, n)) > 1.5).astype(int)

# Combine into a DataFrame for convenience
data = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})

# %% [markdown]
# ## Visualize the Data

# %%
# Scatter plot of the two classes
plt.figure(figsize=(7,6))
plt.scatter(data[data.y==0].x1, data[data.y==0].x2, color='red', alpha=0.5, label='Class 0')
plt.scatter(data[data.y==1].x1, data[data.y==1].x2, color='blue', alpha=0.5, label='Class 1')
plt.title("Synthetic Data")
plt.xlabel("x1")
plt.ylabel("x2")
plt.legend()
plt.show()

# %% [markdown]
# ## Split Data into Training and Test Sets

# %%
# Split data: 70% train, 30% test
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42, shuffle=True)

# Separate features and target for training and testing
X_train = train_data[['x1', 'x2']].values
y_train = train_data['y'].values
X_test = test_data[['x1', 'x2']].values
y_test = test_data['y'].values

# %% [markdown]
# ## Build the Neural Network Model

# %%
# Build a simple feedforward neural network using Keras Sequential API
model = keras.Sequential([
    keras.layers.Input(shape=(2,)),           # Input layer: 2 features
    keras.layers.Dense(10, activation='sigmoid'),  # Hidden layer: 10 neurons, sigmoid activation
    keras.layers.Dense(1, activation='sigmoid')    # Output layer: 1 neuron, sigmoid activation for binary classification
])

# Print model summary to see architecture
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compile the Model

# %%
# Compile the model with binary crossentropy loss, Adam optimizer, and accuracy metric
model.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=0.1),
    metrics=['accuracy']
)

# %% [markdown]
# ## Train the Neural Network

# %%
# Train the model on the training data
# epochs: number of times to iterate over the training data
# batch_size: number of samples per gradient update
# verbose=1: show progress bar
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4811 - loss: 0.7451 - val_accuracy: 0.5633 - val_loss: 0.6935
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5775 - loss: 0.6655 - val_accuracy: 0.6033 - val_loss: 0.6606
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7274 - loss: 0.6011 - val_accuracy: 0.7867 - val_loss: 0.5431
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7883 - loss: 0.4977 - val_accuracy: 0.7767 - val_loss: 0.4580
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.4361 - val_accuracy: 0.8267 - val_loss: 0.4114
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7971 - loss: 0.4345 - val_accuracy: 0.8033 - val_loss: 0.4135
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7886 - loss: 0.4568 - val_accuracy: 0.7867 - val_loss: 0.4258
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8008 - loss: 0.4262 - val_accuracy: 0.8200 - val_loss: 0.3935
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8052 - loss: 0.4067 - val_accuracy: 0.8200 - val_loss: 0.4063
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7682 - loss: 0.4533 - val_accuracy: 0.8233 - val_loss: 0.3984
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7874 - loss: 0.4265 - val_accuracy: 0.8200 - val_loss: 0.3967
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8199 - loss: 0.4136 - val_accuracy: 0.8100 - val_loss: 0.4126
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8001 - loss: 0.4298 - val_accuracy: 0.8133 - val_loss: 0.4333
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7943 - loss: 0.4117 - val_accuracy: 0.8367 - val_loss: 0.4166
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8193 - loss: 0.3819 - val_accuracy: 0.8133 - val_loss: 0.3969
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8060 - loss: 0.4020 - val_accuracy: 0.8167 - val_loss: 0.4068
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8319 - loss: 0.3917 - val_accuracy: 0.8100 - val_loss: 0.3985
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8163 - loss: 0.4157 - val_accuracy: 0.8133 - val_loss: 0.4000
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8092 - loss: 0.4206 - val_accuracy: 0.8200 - val_loss: 0.4004
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8284 - loss: 0.3820 - val_accuracy: 0.8233 - val_loss: 0.4144
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8385 - loss: 0.3924 - val_accuracy: 0.8267 - val_loss: 0.4147
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.3819 - val_accuracy: 0.8233 - val_loss: 0.3971
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8213 - loss: 0.4069 - val_accuracy: 0.8167 - val_loss: 0.3964
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.4210 - val_accuracy: 0.7833 - val_loss: 0.4079
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8070 - loss: 0.4115 - val_accuracy: 0.8300 - val_loss: 0.3986
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8302 - loss: 0.3926 - val_accuracy: 0.8267 - val_loss: 0.4101
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8204 - loss: 0.3887 - val_accuracy: 0.8133 - val_loss: 0.4089
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.4021 - val_accuracy: 0.8133 - val_loss: 0.4421
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8278 - loss: 0.3651 - val_accuracy: 0.8300 - val_loss: 0.4086
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.3839 - val_accuracy: 0.8200 - val_loss: 0.4068
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8332 - loss: 0.3814 - val_accuracy: 0.8300 - val_loss: 0.4058
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8032 - loss: 0.4118 - val_accuracy: 0.8200 - val_loss: 0.4127
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8075 - loss: 0.3932 - val_accuracy: 0.8233 - val_loss: 0.4132
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7984 - loss: 0.4141 - val_accuracy: 0.8333 - val_loss: 0.4037
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7984 - loss: 0.3762 - val_accuracy: 0.8133 - val_loss: 0.4269
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7981 - loss: 0.4171 - val_accuracy: 0.8167 - val_loss: 0.4033
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8089 - loss: 0.4158 - val_accuracy: 0.8000 - val_loss: 0.4489
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7950 - loss: 0.4585 - val_accuracy: 0.8133 - val_loss: 0.4500
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.4144 - val_accuracy: 0.8333 - val_loss: 0.3990
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8262 - loss: 0.3805 - val_accuracy: 0.8200 - val_loss: 0.4046
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8184 - loss: 0.4222 - val_accuracy: 0.8200 - val_loss: 0.4059
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8059 - loss: 0.4054 - val_accuracy: 0.8233 - val_loss: 0.4036
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7998 - loss: 0.4092 - val_accuracy: 0.8100 - val_loss: 0.4016
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.3972 - val_accuracy: 0.8267 - val_loss: 0.4058
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.3954 - val_accuracy: 0.8233 - val_loss: 0.4045
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8069 - loss: 0.3845 - val_accuracy: 0.8267 - val_loss: 0.4097
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8004 - loss: 0.4071 - val_accuracy: 0.8333 - val_loss: 0.4036
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8046 - loss: 0.3993 - val_accuracy: 0.8300 - val_loss: 0.4036
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8422 - loss: 0.3661 - val_accuracy: 0.8200 - val_loss: 0.4001
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.3892 - val_accuracy: 0.8033 - val_loss: 0.4074
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8187 - loss: 0.3904 - val_accuracy: 0.8133 - val_loss: 0.4029
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8214 - loss: 0.3925 - val_accuracy: 0.8300 - val_loss: 0.4178

# %% [markdown]
# ## Plot Training and Validation Accuracy and Loss

# %%
# Plot accuracy and loss curves for training and validation
fig, ax = plt.subplots(1, 2, figsize=(14,5))

# Plot accuracy
ax[0].plot(history.history['accuracy'], label='Train Accuracy')
ax[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
ax[0].set_title('Accuracy over Epochs')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend()
ax[0].grid(True, alpha=0.3)

# Plot loss
ax[1].plot(history.history['loss'], label='Train Loss')
ax[1].plot(history.history['val_loss'], label='Validation Loss')
ax[1].set_title('Loss over Epochs')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend()
ax[1].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# ## Evaluate the Model on Test Data

# %%
# Predict probabilities on test set
y_pred_prob = model.predict(X_test, verbose=0)

# Convert probabilities to binary class predictions (threshold 0.5)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

# Compute confusion matrix and accuracy
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)
print("Confusion Matrix:\n", cm)
print(f"Accuracy: {acc:.4f}")
# Out:
# Confusion Matrix:
#  [[135  14]
#  [ 37 114]]
# Accuracy: 0.8300

# %% [markdown]
# ## Plot Decision Boundary

# %%
# Create a mesh grid for plotting the decision boundary
x1_min, x1_max = data.x1.min() - 0.5, data.x1.max() + 0.5
x2_min, x2_max = data.x2.min() - 0.5, data.x2.max() + 0.5
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max, 200),
                       np.linspace(x2_min, x2_max, 200))
grid_points = np.c_[xx1.ravel(), xx2.ravel()]

# Predict probabilities for each point in the grid
grid_pred_prob = model.predict(grid_points)
grid_pred = (grid_pred_prob > 0.5).astype(int).reshape(xx1.shape)

# Plot the decision boundary and data points
plt.figure(figsize=(8,6))
plt.scatter(data[data.y==0].x1, data[data.y==0].x2, color='red', alpha=0.5, label='Class 0')
plt.scatter(data[data.y==1].x1, data[data.y==1].x2, color='blue', alpha=0.5, label='Class 1')
plt.contour(xx1, xx2, grid_pred, levels=[0.5], colors='k', linewidths=2)
plt.title("Decision Boundary of the Neural Network")
plt.xlabel("x1")
plt.ylabel("x2")
plt.legend()
plt.show()
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 251us/step

# %% [markdown]
# ## Conclusion
#
# In this notebook, we constructed a basic neural network for binary classification using TensorFlow/Keras. We covered the essential components of neural networks and demonstrated how to train and evaluate a neural network on synthetic data. The model's decision boundary was visualized to understand how it classifies the data. Remarkably, the results look very similar to what we achieved in when we code our NNs from scratch.
